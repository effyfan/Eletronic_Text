# %% [markdown]
# # Scraping html with beautifulshoup

# %%
import requests

# %%
reap = requests.get("http://static.decontextualize.com/kittens.html")

# %%
reap.text
# Out:
# '<!doctype html>\n<html>\n\t<head>\n\t\t<title>Kittens!</title>\n\t\t<style type="text/css">\n\t\t\tspan.lastcheckup { font-family: "Courier", fixed; font-size: 11px; }\n\t\t</style>\n\t</head>\n\t<body>\n\t\t<h1>Kittens and the TV Shows They Love</h1>\n\t\t<div class="kitten">\n\t\t\t<h2>Fluffy</h2>\n\t\t\t<div><img src="http://placekitten.com/120/120"></div>\n\t\t\t<ul class="tvshows">\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.com/title/tt0106145/">Deep Space Nine</a>\n\t\t\t\t</li>\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.com/title/tt0088576/">Mr. Belvedere</a>\n\t\t\t\t</li>\n\t\t\t</ul>\n\t\t\tLast check-up: <span class="lastcheckup">2014-01-17</span>\n\t\t</div>\n\t\t<div class="kitten">\n\t\t\t<h2>Monsieur Whiskeurs</h2>\n\t\t\t<div><img src="http://placekitten.com/110/110"></div>\n\t\t\t<ul class="tvshows">\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.com/title/tt0106179/">The X-Files</a>\n\t\t\t\t</li>\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.c
# ...

# %%
html_str = reap.text

# %%
html_str
# Out:
# '<!doctype html>\n<html>\n\t<head>\n\t\t<title>Kittens!</title>\n\t\t<style type="text/css">\n\t\t\tspan.lastcheckup { font-family: "Courier", fixed; font-size: 11px; }\n\t\t</style>\n\t</head>\n\t<body>\n\t\t<h1>Kittens and the TV Shows They Love</h1>\n\t\t<div class="kitten">\n\t\t\t<h2>Fluffy</h2>\n\t\t\t<div><img src="http://placekitten.com/120/120"></div>\n\t\t\t<ul class="tvshows">\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.com/title/tt0106145/">Deep Space Nine</a>\n\t\t\t\t</li>\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.com/title/tt0088576/">Mr. Belvedere</a>\n\t\t\t\t</li>\n\t\t\t</ul>\n\t\t\tLast check-up: <span class="lastcheckup">2014-01-17</span>\n\t\t</div>\n\t\t<div class="kitten">\n\t\t\t<h2>Monsieur Whiskeurs</h2>\n\t\t\t<div><img src="http://placekitten.com/110/110"></div>\n\t\t\t<ul class="tvshows">\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.com/title/tt0106179/">The X-Files</a>\n\t\t\t\t</li>\n\t\t\t\t<li>\n\t\t\t\t\t<a href="http://www.imdb.c
# ...

# %%
from bs4 import BeautifulSoup

# %%
document = BeautifulSoup(html_str, "html.parser")

# %%
type(document)
# Out:
# bs4.BeautifulSoup

# %%
document
# Out:
# <!DOCTYPE doctype html>
#
# <html>
# <head>
# <title>Kittens!</title>
# <style type="text/css">
# 			span.lastcheckup { font-family: "Courier", fixed; font-size: 11px; }
# 		</style>
# </head>
# <body>
# <h1>Kittens and the TV Shows They Love</h1>
# <div class="kitten">
# <h2>Fluffy</h2>
# <div><img src="http://placekitten.com/120/120"/></div>
# <ul class="tvshows">
# <li>
# <a href="http://www.imdb.com/title/tt0106145/">Deep Space Nine</a>
# </li>
# <li>
# <a href="http://www.imdb.com/title/tt0088576/">Mr. Belvedere</a>
# </li>
# </ul>
# 			Last check-up: <span class="lastcheckup">2014-01-17</span>
# </div>
# <div class="kitten">
# <h2>Monsieur Whiskeurs</h2>
# <div><img src="http://placekitten.com/110/110"/></div>
# <ul class="tvshows">
# <li>
# <a href="http://www.imdb.com/title/tt0106179/">The X-Files</a>
# </li>
# <li>
# <a href="http://www.imdb.com/title/tt0098800/">Fresh Prince</a>
# </li>
# </ul>
# 			Last check-up: <span class="lastcheckup">2013-11-02</span>
# </div>
# ...

# %%
h1_tag = document.find('h1')

# %%
type(h1_tag)
# Out:
# bs4.element.Tag

# %%
h1_tag
# Out:
# <h1>Kittens and the TV Shows They Love</h1>

# %%
h1_tag.string
# Out:
# 'Kittens and the TV Shows They Love'

# %%
img_tag = document.find('img')

# %%
img_tag
# Out:
# <img src="http://placekitten.com/120/120"/>

# %%
img_tag["src"]
# Out:
# 'http://placekitten.com/120/120'

# %%
h2_tags = document.find_all('h2')

# %%
type(h2_tags)
# Out:
# bs4.element.ResultSet

# %%
h2_tags
# Out:
# [<h2>Fluffy</h2>, <h2>Monsieur Whiskeurs</h2>]

# %%
h2_tags[0].string
# Out:
# 'Fluffy'

# %%
h2_tags[1].string
# Out:
# 'Monsieur Whiskeurs'

# %%
[item.string for item in h2_tag]
# Out:
# ['Fluffy', 'Monsieur Whiskeurs']

# %%
img_tags = document.find_all("img")

# %%
img_tags
# Out:
# [<img src="http://placekitten.com/120/120"/>,
#  <img src="http://placekitten.com/110/110"/>]

# %%
type(img_tags)
# Out:
# bs4.element.ResultSet

# %%
img_tags[1].string ## errr no string in img tags

# %%
img_tags[0]["src"]
# Out:
# 'http://placekitten.com/120/120'

# %%
img_tags[1]["src"]
# Out:
# 'http://placekitten.com/110/110'

# %%
[item["src"] for item in img_tags]
# Out:
# ['http://placekitten.com/120/120', 'http://placekitten.com/110/110']

# %%
checkups = document.find_all("span", attrs={'class': 'lastcheckup'})

# %%
checkups
# Out:
# [<span class="lastcheckup">2014-01-17</span>,
#  <span class="lastcheckup">2013-11-02</span>]

# %%
[item.string for item in checkups]
# Out:
# ['2014-01-17', '2013-11-02']

# %% [markdown]
# ## kitten tags

# %%
kitten_tags = document.find_all("div", attrs={"class": "kitten"})

# %%
kitten_tags[0]
# Out:
# <div class="kitten">
# <h2>Fluffy</h2>
# <div><img src="http://placekitten.com/120/120"/></div>
# <ul class="tvshows">
# <li>
# <a href="http://www.imdb.com/title/tt0106145/">Deep Space Nine</a>
# </li>
# <li>
# <a href="http://www.imdb.com/title/tt0088576/">Mr. Belvedere</a>
# </li>
# </ul>
# 			Last check-up: <span class="lastcheckup">2014-01-17</span>
# </div>

# %%
type(kitten_tags[0])
# Out:
# bs4.element.Tag

# %%
type(kitten_tags)
# Out:
# bs4.element.ResultSet

# %%
kitten_tags # a list of tag objects
# Out:
# [<div class="kitten">
#  <h2>Fluffy</h2>
#  <div><img src="http://placekitten.com/120/120"/></div>
#  <ul class="tvshows">
#  <li>
#  <a href="http://www.imdb.com/title/tt0106145/">Deep Space Nine</a>
#  </li>
#  <li>
#  <a href="http://www.imdb.com/title/tt0088576/">Mr. Belvedere</a>
#  </li>
#  </ul>
#  			Last check-up: <span class="lastcheckup">2014-01-17</span>
#  </div>, <div class="kitten">
#  <h2>Monsieur Whiskeurs</h2>
#  <div><img src="http://placekitten.com/110/110"/></div>
#  <ul class="tvshows">
#  <li>
#  <a href="http://www.imdb.com/title/tt0106179/">The X-Files</a>
#  </li>
#  <li>
#  <a href="http://www.imdb.com/title/tt0098800/">Fresh Prince</a>
#  </li>
#  </ul>
#  			Last check-up: <span class="lastcheckup">2013-11-02</span>
#  </div>]

# %%
first_kitten = kitten_tags[0]

# %%
first_kitten.find("h2")
# Out:
# <h2>Fluffy</h2>

# %%
for item in kitten_tags:
    this_h2 = item.find("h2")
    print(this_h2.string)
# Out:
# Fluffy
# Monsieur Whiskeurs

# %%
for item in kitten_tags:
    this_h2 = item.find("h2")
    print(this_h2.string)
    li_tags = item.find_all('li')
    print(li_tags)
# Out:
# Fluffy
# [<li>
# <a href="http://www.imdb.com/title/tt0106145/">Deep Space Nine</a>
# </li>, <li>
# <a href="http://www.imdb.com/title/tt0088576/">Mr. Belvedere</a>
# </li>]
# Monsieur Whiskeurs
# [<li>
# <a href="http://www.imdb.com/title/tt0106179/">The X-Files</a>
# </li>, <li>
# <a href="http://www.imdb.com/title/tt0098800/">Fresh Prince</a>
# </li>]

# %%
for item in kitten_tags:
    this_h2 = item.find("h2")
    print(this_h2.string)
    a_tags = item.find_all('a')
    print(a_tags)
# Out:
# Fluffy
# [<a href="http://www.imdb.com/title/tt0106145/">Deep Space Nine</a>, <a href="http://www.imdb.com/title/tt0088576/">Mr. Belvedere</a>]
# Monsieur Whiskeurs
# [<a href="http://www.imdb.com/title/tt0106179/">The X-Files</a>, <a href="http://www.imdb.com/title/tt0098800/">Fresh Prince</a>]

# %%
for item in kitten_tags:
    this_h2 = item.find("h2")
    print(this_h2.string)
    a_tags = item.find_all('a')
    a_tags_str = [t.string for t in a_tags]  # because there are 2 a_tags in each h2, we need for loop to make each one of them into string
    print(", ".join(a_tags_str))
# Out:
# Fluffy
# Deep Space Nine, Mr. Belvedere
# Monsieur Whiskeurs
# The X-Files, Fresh Prince

# %%
for item in kitten_tags:
    this_h2 = item.find("h2")
    kitten_name = this_h2.string
    a_tags = item.find_all('a')
    a_tags_str = [t.string for t in a_tags]
    kitten_shows = ", ".join(a_tags_str)
    print(kitten_name + ": " + kitten_shows)
# Out:
# Fluffy: Deep Space Nine, Mr. Belvedere
# Monsieur Whiskeurs: The X-Files, Fresh Prince

# %% [markdown]
# ## Data structure
#
# list of dictionaries
#     [
#         {'name': Fluffy, 'shows': ['Deep Space Nine', 'Mr.Belvedere]}
#         ...
#     ]

# %%
kitten_list = []

for item in kitten_tags:
    this_h2 = item.find("h2")
    kitten_name = this_h2.string
    a_tags = item.find_all('a')
    a_tags_str = [t.string for t in a_tags]
    kitten_shows = ", ".join(a_tags_str)
    this_kitten = {'name': kitten_name, 'shows': a_tags_str}
    kitten_list.append(this_kitten)

# %%
kitten_list
# Out:
# [{'name': 'Fluffy', 'shows': ['Deep Space Nine', 'Mr. Belvedere']},
#  {'name': 'Monsieur Whiskeurs', 'shows': ['The X-Files', 'Fresh Prince']}]

# %%
[item["name"] for item in kitten_list]
# Out:
# ['Fluffy', 'Monsieur Whiskeurs']

# %% [markdown]
# ## sibling tags
#
# cheesedoc = BeautifulSoup(some_html)
#
# h2.find_next_sibling('p')

# %% [markdown]
# # BREAK

# %%
reap2 = requests.get("https://tisch.nyu.edu/itp/news")

# %%
html_str2 = reap2.text

# %%
print(html_str2)
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html lang="en" class="no-js" data-resourcetype="tisch/components/pages/news-landing" data-path="/content/tisch/programs-departments/itp/news" xmlns:og="http://opengraphprotocol.org/schema/"> <!--<![endif]-->
#
#
#
#
#
#
#
#
#
#
#
# <head>
#
#
#         <meta charset="utf-8"/>
#         <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1"/>
#
#         <link rel="shortcut icon" href="/etc/designs/tisch/favicon.ico"/>
#
#         <title>News</title>
#         <meta name="description" content="News items featuring ITP and IMA students, alumni and faculty."/>
#         <meta name="meta-description" content="News items featuring ITP and IMA students, alumni and faculty."/>
# ...

# %%
 html_str2.find("media-content__wrap")   # not the beautiful soup find
# Out:
# 55688

# %%
document = BeautifulSoup(html_str2, "html.parser")

# %%
news_items = document.find_all("div", {"class": "media-content__wrap"})

# %%
for item in news_items:
    blurb_tag = item.find("p", {"class": "media-item__content--maj"})
    print(blurb_tag)
# Out:
# <p class="media-item__content--maj">ITP Second Year Student Sean Kim has been invited to attend the 2018 Dalai Lama Fellows Global (Ethical Leadership) Assembly.</p>
# <p class="media-item__content--maj">Climojis, a product of ITP Alums and Faculty were written up in ScienceLine this month.</p>
# <p class="media-item__content--maj">ITP Faculty member Clay Shirky was on WNYC's "Big, If True" Program on March 23rd, discussing the Cambridge Analytica scandal.</p>
# <p class="media-item__content--maj">ITP Alum Sharang Biswas has a game exhibition opening in April at the Institute of Contemporary Art in Philadelphia.</p>
# <p class="media-item__content--maj">ITP Alum Susan Leopold has opening for exhibit "Intersections" at Elizabeth Harris Gallery on Saturday, March 31st at 3-6pm. </p>
# <p class="media-item__content--maj">ITP Student Barak Chamo has been selected for New Rochelle's IDEALab Fellowship.</p>
# <p class="media-item__content--maj">Verizon's Demo Day is coming up!</p>
# ...

# %%
for item in news_items:
    first_a = item.find("a")
    title = first_a.string
    blurb_tag = item.find("p", {"class": "media-item__content--maj"})
    blurb = blurb_tag.string
    date_tag = item.find("p", {"class": "media-title--minor"})
    date = date_tag.string
    print(title, blurb, date)
# Out:
# ITP Student to Present for Dalai Lama Global Fellows ITP Second Year Student Sean Kim has been invited to attend the 2018 Dalai Lama Fellows Global (Ethical Leadership) Assembly. Thursday, Mar 29, 2018
# Climojis Written Up in ScienceLine Climojis, a product of ITP Alums and Faculty were written up in ScienceLine this month. Monday, Mar 26, 2018
# ITP Faculty on WNYC Program ITP Faculty member Clay Shirky was on WNYC's "Big, If True" Program on March 23rd, discussing the Cambridge Analytica scandal. Monday, Mar 26, 2018
# ITP Alum Performing at Institute of Contemporary Art ITP Alum Sharang Biswas has a game exhibition opening in April at the Institute of Contemporary Art in Philadelphia. Monday, Mar 26, 2018
# ITP Alum has Art Opening at Elizabeth Harris Gallery ITP Alum Susan Leopold has opening for exhibit "Intersections" at Elizabeth Harris Gallery on Saturday, March 31st at 3-6pm.  Monday, Mar 26, 2018
# ...

# %% [markdown]
# ## with image

# %%
import time

# %%
news_lis = document.find_all('li', {"class": "media-item--maj"})

# %%
prefix = "https://tisch.nyu.edu"
for item in news_lis:
    img_tag = item.find("img")
    url = prefix + img_tag["src"]
    img_reap = requests.get(url)
    fname = url.split("/")[-1]
    open(fname, "wb").write(img_reap.content)
    time.sleep(0.5)
    print(fname)
# Out:
# dalailamafellows.png
# climoji.jpg
# clayshirkyfacebook.jpg
# feast.png
# intersections.png
# idealabfellowship.png
# demoday.jpg
# processingsettings.png
# volume.jpg
# soundchecklori.jpg
